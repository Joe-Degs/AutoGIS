# %%
from autogis import *

# %%
a = Route('coords_list', [(6.7001, -1.62217), (6.70312, -1.62511)], [(6.69791, -1.61829), (6.6971, -1.62252)])

# %%
# a.explore(**plot_args())

# %%
g = Graph('route', a.graph)

# %%
g.static_plot()
# Out:
# C:\Users\big yeti\autogis\test-thesis\autogis\route.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.all_geo = self.origin_geo.append(self.dest_geo)
# (<Figure size 720x720 with 1 Axes>, <AxesSubplot:>)

# %%
g.static_plot(tiles=True, linewidth=1.5,
                 axis=False, node_size=6,
                 line_alpha=0.7, nodes=False,
                 static_tile=ctx.providers.CartoDB.DarkMatterNoLabels,
                 title='Neigbourhood in Adum - Street Network (Drive)',
                 filepath='yikes_plot.png')
# Out:
# (<Figure size 720x720 with 1 Axes>,
#  <AxesSubplot:title={'center':'Neigbourhood in Adum - Street Network (Drive)'}>)
