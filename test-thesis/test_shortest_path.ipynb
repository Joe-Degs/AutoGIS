# %%
from autogis import *

# %%
a = Route('coords_list', [(6.7001, -1.62217), (6.70312, -1.62511)], [(6.69791, -1.61829), (6.6971, -1.62252)])

# %%
g = Graph('route_polygon', a)

# %%
g.download(network_type='drive').static_plot(basemap=False, color='red', markersize=5, axis=False)
# Out:
# C:\Users\big yeti\autogis\test-thesis\autogis\route.py:104: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.all_geo = self.origin_geo.append(self.dest_geo)
# (<Figure size 720x720 with 1 Axes>, <AxesSubplot:>)

# %%
g.shortest_path_with_route(a)
# Out:
# names of cols with unhashable types: [('y', False), ('x', False), ('street_count', False), ('lon', False), ('lat', False), ('highway', False), ('geometry', False)]
# returning: {cols}
# names of cols with unhashable types: [('osmid', True), ('name', True), ('highway', False), ('oneway', False), ('length', False), ('geometry', False), ('bridge', False), ('lanes', False), ('junction', False), ('width', False), ('ref', False)]
# returning: {cols}
# C:\ProgramData\Anaconda3\envs\ox\lib\site-packages\pandas\core\common.py:241: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = np.asarray(values, dtype=dtype)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ...
